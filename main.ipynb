# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# Out:
# /home/aumpatel/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('mushroom.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
#    Unnamed: 0 cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0           0         x           s         n       t    p               f
# 1           1         x           s         y       t    a               f
# 2           2         b           s         w       t    l               f
# 3           3         x           y         w       t    p               f
# 4           4         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-color-above-ring  \
# 0            c         n          k  ...                      w
# 1            c         b          k  ...                      w
# 2            c         b          n  ...                      w
# 3            c         n          n  ...                      w
# 4            w         b          k  ...                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# 1                      w         p          w           o         p
# 2                      w         p          w           o         p
# 3                      w         p          w           o         p
# 4                      w         p          w           o         e
#
#   spore-print-color population habitat poisonous
# 0                 k          s       u         p
# 1                 n          n       g         e
# 2                 n          n       m         e
# 3                 k          s       u         p
# 4                 n          a       g         e
#
# [5 rows x 24 columns]

# %%
# Display the amount of missing data in each column
missing_data = df.isnull().sum()
print(missing_data)
# Out:
# Unnamed: 0                     0
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises                        0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                  2480
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                    0
# ring-type                      0
# spore-print-color              0
# population                     0
# habitat                        0
# poisonous                      0
# dtype: int64
